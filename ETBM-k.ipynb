# %%
rm(list=ls())
library("Seurat")
library("ggplot2")

scrna<-readRDS("renamed_ETBM.rds")
# Out:
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, were retired in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
#
# Attaching SeuratObject

# %%
sessionInfo()
# Out:
# R version 4.3.1 (2023-06-16)
# Platform: aarch64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.6 LTS
#
# Matrix products: default
# BLAS/LAPACK: /root/miniconda3/envs/R4.3/lib/libopenblasp-r0.3.23.so;  LAPACK version 3.11.0
#
# locale:
#  [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8
#  [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C
# [10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Etc/UTC
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] digest_0.6.33     IRdisplay_1.1     utf8_1.2.3        base64enc_0.1-3
#  [5] fastmap_1.1.1     glue_1.6.2        htmltools_0.5.6.1 repr_1.1.6
#  [9] lifecycle_1.0.3   cli_3.6.1         fansi_1.0.5       vctrs_0.6.4
# ...

# %%
p1 = VlnPlot(scrna,features = "LGALS1",pt.size=0, split.by ='DataSet')
p3 = FeaturePlot(scrna,features = "LGALS1")
p1|p3
# Out:
# plot without title

# %%
dim(scrna)
# Out:
# [1] 17772 22701

# %%
rownames(scrna)
# Out:
#     [1] "AL627309.5"        "LINC01409"         "LINC01128"
#     [4] "LINC00115"         "AL645608.6"        "NOC2L"
#     [7] "ISG15"             "C1orf159"          "TTLL10"
#    [10] "SDF4"              "B3GALT6"           "UBE2J2"
#    [13] "LINC01786"         "SCNN1D"            "ACAP3"
#    [16] "PUSL1"             "INTS11"            "CPTP"
#    [19] "DVL1"              "AURKAIP1"          "CCNL2"
#    [22] "MRPL20-AS1"        "MRPL20"            "ANKRD65"
#    [25] "VWA1"              "ATAD3C"            "ATAD3B"
#    [28] "ATAD3A"            "SSU72"             "AL645728.1"
#    [31] "FNDC10"            "AL691432.4"        "AL691432.2"
#    [34] "MIB2"              "CDK11B"            "SLC35E2B"
#    [37] "CDK11A"            "SLC35E2A"          "NADK"
#    [40] "GNB1"              "PRKCZ"             "FAAP20"
#    [43] "SKI"               "AL590822.3"        "MORN1"
#    [46] "RER1"              "PEX10"             "PANK4"
# ...

# %%
head(scrna)
# Out:
#                      orig.ident nCount_RNA nFeature_RNA DataSet percent.mt
# AAACCCAAGTGCCCGT-1_1 ET1        15262      4084         ET       6.761892
# AAACCCAGTCAACACT-1_1 ET1        10560      3334         ET       6.988636
# AAACCCATCAAGAGGC-1_1 ET1        13645      4228         ET       6.207402
# AAACCCATCCATAGGT-1_1 ET1        10238      3603         ET       5.547959
# AAACCCATCCCAGGCA-1_1 ET1         9339      3438         ET       5.643002
# AAACCCATCCTAAGTG-1_1 ET1        16413      4776         ET       3.929812
# AAACCCATCGAGCCAC-1_1 ET1        14754      4373         ET       4.026027
# AAACCCATCTGGCCAG-1_1 ET1        12713      3844         ET       5.639896
# AAACGAAAGCTACTGT-1_1 ET1        11316      4012         ET      18.769883
# AAACGAACAAAGACTA-1_1 ET1        17252      4844         ET       2.904011
#                      percent.ribo RNA_snn_res.0.8 seurat_clusters singlr_labels
# AAACCCAAGTGCCCGT-1_1  3.623378    7               7               Monocyte
# ...

# %%
table(scrna$celltype)
# Out:
#  CMP MONO  MEP  HSC  GMP  LYM
# 7134 3957 3101 3881 4338  290

# %%
table(scrna$singlr_labels)
# Out:
#         Astrocyte            B_cell                BM        BM & Prog.
#                 1               210                 2                49
#               CMP                DC Endothelial_cells      Erythroblast
#             12933                 1                 3                13
#               GMP        HSC_-G-CSF         HSC_CD34+        Macrophage
#              1503                23               665                 9
#               MEP          Monocyte         Myelocyte           Neurons
#              2104              3870                13                 1
#       Neutrophils           NK_cell         Platelets  Pre-B_cell_CD34-
#                21               172                28                38
#  Pro-B_cell_CD34+     Pro-Myelocyte           T_cells Tissue_stem_cells
#               930                18                92                 2

# %%
tiff("GALECTINS_BMMC.tiff", units="in", res=300, height=5, width=5.5)

# %%
p1 = VlnPlot(scrna,features = "LGALS1",pt.size=0, split.by ='DataSet')
p2 = VlnPlot(scrna,features = "LGALS3",pt.size=0, split.by ='DataSet')
p3 = FeaturePlot(scrna,features = "LGALS1")
p4 = FeaturePlot(scrna,features = "LGALS3")
print((p1/p2)|(p3/p4))
dev.off()
# Out:
# tiff
#    3
# plot without title

# %%
(p1/p2)|(p3/p4)
# Out:
# plot without title

# %%
p1
# Out:
# plot without title
